# %% [markdown]
# # takes string and convert to Exel File

# %%
import pandas as pd

data= """
M5	DD1094-608
M10	DO6485-600
M15	DQ6215-001
M16	DX2498-600
M17	DX2498-001
M20	DV1694-900
M25	FB1312-001
M30	CW1589-100
M33	
M35	DQ6048-100
M38	BQ7197-301
M39	FN3878-001
M40 DQ8423-616
N1	DA4087-100
N2	FD0694-100
N5	DD1095-003
N10	DA4086-109
N11	BQ6066-215
N12	FD0689-001
N13	528896-140
N15	DQ6201-001
N21	DZ5633-800
N22	FJ3487-100
N23	FD0300-600
N35	
N40	DA4086-008
N45	CT3839-100
N50	DZ5631-001
N55	DD2314-111
N60	DV1624-001
N70	DH9388-003
O1	DA4086-100
O5	DR5709-002
O10	DH2925-111
O15	DH2926-111
O16	DX5545-400
O17	AR6352-136
O18	DV7026-108
O25	DJ6039-600
O30	DD1646-002
O40	
O41	DD1094-100
O42	FD1233-002
O43	DV8919-100
O44	DQ8433-016
O45	CW1590-100
O46	BQ7196-301
O47	CW1588-100
O50	DM0967-100
O51	DZ5634-800
O55	DR6496-116
O70	DH9761-003
O75	AO2372-026
O80	DB2179-110
O85	DD2314-109
O87	CJ4113-002
O95	CD6868-022
O100 DH2920-111
O105	
P1	BQ7196-016
P5	DQ6202-001
P10	DA4086-010
P11	FD0673-400
P20	FD1232-001
P26	DB2179-007
P30	DM4015-002
P40	
P41	
P42	
P45	DH9756-003
P46	FB1313-001
P50	DA3199-001
P55	DV1323-100
P56	FD2597-700
P57	555766-146
P58	DH9765-001
P60	554725-136
P65	DQ8400-106
P67	CW1590-600
P70	CT3839-107
P71	FD1232-002
P72	FB8022-001
P75	BQ7197-016
P76	DV1623-001
P77	DV1621-001
P80	DJ6040-002
P81	FB8038-001
P82	DQ8424-501
P90	CZ1685-104
P95	DN1431-002
Q1	DD1096-600
Q2	
Q3	DA4087-110
Q4	BQ7670-017
Q5	DV1693-401
Q10	DX9282-100
Q30	DQ8398-106
Q35	DD1095-600
Q40	DQ5973-200
Q45	
Q46	
Q47	553560-136
Q48	DR5709-400
Q49	DV1970-002
R1	DD1094-400
R5	DA4088-100
R10	BV1094-100
R11	DX5545-002
R30	943345-001
R34	DD2314-006
R35	CI7850-610
S1	FD1228-002
S2	DV1988-001
S5	DQ8398-001
S10	DD1094-600
S15	CD6867-022
S20	
S25	AO2372-001
S30	BQ7197-001
S33	DV1970-003
S34	DH9756-001
S35	DV7012-100
S36	FB4418-016
S37	CW3360-010
"""





# Split the data into rows
rows = [line.split()[:2] for line in data.strip().split("\n")]

# Create a DataFrame from the rows
df = pd.DataFrame(rows, columns=["Location", "Stock Number"])

# Save to Excel
output_file = "kids.xlsx"
df.to_excel(output_file, index=False)

print("Data successfully converted to Excel and saved in",output_file)
# Out:
# Data successfully converted to Excel and saved in kids.xlsx
